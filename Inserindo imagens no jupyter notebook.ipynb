# %% [markdown]
# # Maneira #1 Usando a Calsse Image

# %%
from IPython.display import Image

# %%
Image(filename="Ex05.png", width=900)

# %% [markdown]
# # Maneira #2

# %% [markdown]
# Via markdown. Selecionar opção "markdown".

# %% [markdown]
# ## Via local

# %% [markdown]
# ![](Ex05.png)

# %% [markdown]
# ## Via web

# %% [markdown]
# ![Image of Yaktocat](https://octodex.github.com/images/topguntocat.png)

# %% [markdown]
# # Maneira #3 Via HTML

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= 'https://octodex.github.com/images/goretocat.png')
# Out:
# <img src="https://octodex.github.com/images/goretocat.png"/>

# %%
Image(url= 'https://octodex.github.com/images/daftpunktocat-guy.gif')
# Out:
# <img src="https://octodex.github.com/images/daftpunktocat-guy.gif"/>

# %% [markdown]
# Pode-se usar tags

# %%
Image(url= 'https://octodex.github.com/images/spidertocat.png', width=500, height=100)
# Out:
# <img src="https://octodex.github.com/images/spidertocat.png" width="500" height="100"/>

# %%
Image(url= 'http://desktopography.net/wp-content/uploads/bfi_thumb/ALONE-34re7d3h27texnipm6f0u8.jpg', width=500, height=100)
# Out:
# <img src="http://desktopography.net/wp-content/uploads/bfi_thumb/ALONE-34re7d3h27texnipm6f0u8.jpg" width="500" height="100"/>

# %% [markdown]
# # Maneira #4

# %% [markdown]
# Via matplotlib

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
image = mpimg.imread("Ex05.png")
plt.imshow(image)
plt.show()

# %% [markdown]
# # Maneira #5 sem precisar "digitar"

# %% [markdown]
# ![Maneira#6.JPG](attachment:Maneira#6.JPG)

# %% [markdown]
# <img src="Ex05.png", width=200, height=200>
